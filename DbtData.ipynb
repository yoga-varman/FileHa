# %%
import glob
from pyspark.sql import SparkSession 
from pyspark.sql import functions as F
from pyspark.sql import types as T
import pandas as pd

# %%
file_path = "/mnt/d/all_data/20260903/GIS_11,340 Students list(Batch 1).xlsx"

df = pd.read_excel(file_path, engine="openpyxl")

# %%
df = df[["aadhaar_no", "student_name", "application_id","scholarship_amount","mobile_no"]]

# %%
# benificiary_id
# installment_id
# benificiary_reference_id
# benificiary_name
# benificiary_mobile_no
# adhaar_no
# amount
# payment_mode_id
# district_code
# taluk_code
# jurisdiction_layer_code
# jurisdiction_code
# benificiary_account_no
# benificiary_bank_name
# benificiary_ifsc_code
# benificiary_iin_no

# %%
import pandas as pd

file_path = "/mnt/d/all_data/20260909/AY 26-27 EMIS DBT payment file(TW) 9022_1.csv"

df = pd.read_csv(file_path)

print(df.head())
print(df.columns)
# Out:
#                    benificiary_id  installment_id  benificiary_reference_id  \
# 0  TNISSPEMIS20260019000521318433               1                       NaN
# 1  TNISSPEMIS20260019000521306100               1                       NaN
# 2  TNISSPEMIS20260019000522267710               1                       NaN
# 3  TNISSPEMIS20260019000521617740               1                       NaN
# 4  TNISSPEMIS20260019000521830117               1                       NaN
#
#   benificiary_name  benificiary_mobile_no     adhaar_no  amount  \
# 0      V VINODHINI           7.305322e+09  809623350623     500
# 1          RAMYA K           9.514622e+09  734861688902     500
# 2       PRAVEENA B           9.344976e+09  482217171415     500
# 3       INIYASRI S           9.962329e+09  281145643660     500
# 4       RASHMIGA E           9.342667e+09  511197252316     500
#
#   payment_mode_id  district_code  taluk_code  jurisdiction_layer_code  \
# 0             ACH            730         NaN                      NaN
# 1             ACH            574         NaN                      NaN
# 2             ACH            572         NaN                      NaN
# 3             ACH            732         NaN                      NaN
# 4             ACH            571         NaN                      NaN
#
#    jurisdiction_code  benificiary_account_no  benificiary_bank_name  \
# 0                NaN                     NaN                    NaN
# 1                NaN                     NaN                    NaN
# 2                NaN                     NaN                    NaN
# 3                NaN                     NaN                    NaN
# 4                NaN                     NaN                    NaN
#
#    benificiary_ifsc_code  benificiary_iin_no
# 0                    NaN                 NaN
# 1                    NaN                 NaN
# 2                    NaN                 NaN
# 3                    NaN                 NaN
# 4                    NaN                 NaN
# Index(['benificiary_id', 'installment_id', 'benificiary_reference_id',
#        'benificiary_name', 'benificiary_mobile_no', 'adhaar_no', 'amount',
#        'payment_mode_id', 'district_code', 'taluk_code',
#        'jurisdiction_layer_code', 'jurisdiction_code',
#        'benificiary_account_no', 'benificiary_bank_name',
#        'benificiary_ifsc_code', 'benificiary_iin_no'],
#       dtype='str')

# %%
df["benificiary_id"]=df["adhaar_no"]
df["installment_id"]="1"
df["benificiary_reference_id"]=df["benificiary_id"]
df["benificiary_name"]=df["benificiary_name"]
df["benificiary_mobile_no"]=df["benificiary_mobile_no"]
df["adhaar_no"]=df["adhaar_no"]
df["amount"]=df["amount"]
df["payment_mode_id"]="1"
df["district_code"]="1000"
df["taluk_code"]="1000"
df["jurisdiction_layer_code"]=None
df["jurisdiction_code"]=None
df["benificiary_account_no"]=None
df["benificiary_bank_name"]=None
df["benificiary_ifsc_code"]=None
df["benificiary_iin_no"]=None

# %%
columns = [
    "benificiary_id",
    "installment_id",
    "benificiary_reference_id",
    "benificiary_name",
    "benificiary_mobile_no",
    "adhaar_no",
    "amount",
    "payment_mode_id",
    "district_code",
    "taluk_code",
    "jurisdiction_layer_code",
    "jurisdiction_code",
    "benificiary_account_no",
    "benificiary_bank_name",
    "benificiary_ifsc_code",
    "benificiary_iin_no"
]

df = df[columns]

# %%
for col in df.columns:
    df[col] = (
        df[col]
        .astype("string")
        .str.replace(r"\s+", "", regex=True)
        .str.strip()
    )

# %%
for col in df.columns:
    df[col] = (
        df[col]
        .astype("string")
        .str.replace(r"[^a-zA-Z0-9]", "", regex=True)
    )

# %%
df = df.fillna("").astype(str)

for col in df.columns:
    df[col] = df[col].str.replace(r"\s+", "", regex=True)

# %%
df.to_csv("/mnt/d/all_data/20260909/twtngisbendata.csv", index=False)
